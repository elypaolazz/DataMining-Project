# %% [markdown]
# # **Final data creation**

# %% [markdown]
# #### **Libraries**
#
# We import the necessary libraries.

# %%
import pandas as pd
import json
import random
import datetime
from tqdm import tqdm
import pprint
import sys

PP = pprint.PrettyPrinter(sort_dicts=False, depth=6)
sys.path.append('../')
from utilities import generate_random_date, get_random_id

print("> Libraries Imported")
# Out:
# > Libraries Imported

# %% [markdown]
# #### **Import patients, conditions and therapies**
#
# First, we import intermediate data, i.e condition, therapies and patients data.

# %%
# import conditions and therapies data
with open('intermediate_data/cond_ther.json', 'r') as file:
    cond_and_ther = json.load(file)
# import patients data
with open('intermediate_data/patients.json', 'r') as file:
    patients_dict = json.load(file)

# %% [markdown]
# #### **Create an algorithm for patients conditions and trials generation**
#
# Besides id, name and gender, patients have two other attributes: conditions and trials.
# Each patient may have one or more conditions, which have a diagnosed date and a cured date.
# Each condition has at least one trial, which has a start date, an end date and a success rate.
# The conditions and trials of a patient are identified by an id and refer to the conditions and therapies previously collected and stored (`cond_ther.json`).

# %% [markdown]
# #### **Main Algorithm description**
#
# The patients conditions and trials generation main algorithm is designed as follows:
#
# - takes as input the patient, the list of conditions ids and the list of therapies ids
#
# - modify the conditions key's values:
#     - choose a random number `N` between 1 and 5 and create `N` conditions for that patient
#     - for each condition:
#         - create an `id`
#         - create a random `diagnosed` date
#         - set `cured` date as NULL
#         - choose a random condition id from cond_ther.json data (`kind`)

# %% [markdown]
# - modify the trials key's values:
#     - for each condition:
#         - choose a random number `N` between 1 and 5 and create `N` trials for that condition
#         - for each trial:
#             - create an `id`
#             - create `start` date, which has to be greater than `diagnosed`
#             - create `end` date, which has to be greater than `start`
#             - store condition id in `condition` attrributes
#             - choose a random therapy id from cond_ther.json data (`therapy`)
#             - choose a random number between 0 and 100 for `successful`, if this number is greater than 75, the condition `cured` date is updated with the trial `end` date
#
#
# ##### Main algorithm constraints:
# - Each patient has at least one and and a maximum of 5 conditions;
# - Each patient has at least one and a maximum of 5 trials for each condition;
# - Each patient's conditions are ordered (the diagnosed date of the later condition is greater than the diagnosed date of the earlier one);
# - Each trial start date is greater than the corresponding condition's diagnosed date;
# - Each trials for the same condition are ordered (the start date of the later condition is greater than the start date of the earlier one);
# - If the tiral for a condition is successful, no further tirals are generated for that condition.

# %% [markdown]
# #### **Function code definition**:

# %%
def generate_full_patients(patients_dict, list_of_conditions_ids, list_of_therapies_ids):

   # generate conditions and trials for patients
   for patient_dict in patients_dict['Patients']:
      
      # print(f"> PATIENT '{patient_dict['name']}' [ID: {patient_dict['id']}]")
      
      # CONDITIONS

      # obtain the number of conditions to generate
      NUM_OF_CONDITIONS = random.sample(range(1,6), 1)[0]
      # print(f'  * Number of conditions: {NUM_OF_CONDITIONS}')

      # get a copy of all the possible conditions
      list_of_conditions_ids_copy = list_of_conditions_ids.copy()

      # create N conditions
      for idx in range(NUM_OF_CONDITIONS):

         # create condition dictionary
         temp_condition = {}

         # set 'id' 
         temp_condition['id'] = f'c{idx+1}'

         # generate a random date

         # if conditions are already present for the patient --> get the last date
         if len(patient_dict['conditions']) > 0:
            last_date = patient_dict['conditions'][-1]['diagnosed']
         else:
            last_date = None

         # generate the date
         temp_condition['diagnosed'] = generate_random_date(min_date=last_date, type="condition")

         # set 'cured' to None
         temp_condition['cured'] = None

         # set 'kind' to a random condition id
         temp_cond_id = get_random_id(list_of_conditions_ids_copy)
         temp_condition['kind'] = temp_cond_id
         list_of_conditions_ids_copy.remove(temp_cond_id) # ensure that there are no duplicates conditions

         # add the condition dictionary to the patient
         patient_dict['conditions'].append(temp_condition)

      # TRIALS
      
      for condition in patient_dict['conditions']:

         # setup
         CREATE_NEW_TRIALS = True

         # obtain the number of conditions to generate
         NUM_OF_TRIALS = random.sample(range(1,5), 1)[0]
         # print(f"  * Number of trials for condition '{condition['id']}': {NUM_OF_TRIALS}")

         # get a copy of all the possible therapies
         list_of_therapies_ids_copy = list_of_therapies_ids.copy()

         temp_min_date = condition['diagnosed']
         for idx in range(NUM_OF_TRIALS):

            if CREATE_NEW_TRIALS:

               # create trial dictionary
               temp_trial = {}

               # set 'id' 
               temp_trial['id'] = condition['id'] + f'_t{idx+1}'

               # set 'start'
               temp_trial['start'] = generate_random_date(min_date=temp_min_date, type="trial")

               # set 'end' 
               temp_trial_end = generate_random_date(min_date=temp_trial['start'], type="trial")
               temp_trial['end'] = temp_trial_end
               temp_min_date = temp_trial_end

               # set 'condition'
               temp_trial['condition'] = condition['id']

               # set 'therapy'
               temp_ther_id = get_random_id(list_of_therapies_ids_copy)
               temp_trial['therapy'] = temp_ther_id
               list_of_therapies_ids_copy.remove(temp_ther_id) # ensure that there are no duplicates therapies

               # set 'successful'
               SUCC = random.sample(range(0,100), 1)[0]
               temp_trial['successful'] = SUCC

               if SUCC > 75:
                  condition['cured'] = temp_trial['end']
                  CREATE_NEW_TRIALS = False

               # add the trial dictionary to the patient
               patient_dict['trials'].append(temp_trial)

      # print("-"*100)
   
   return patients_dict

# %% [markdown]
# #### **Function execution**
#
# We can finally execute the function using our patients dictionary.

# %%
# setup
list_of_conditions_ids = [x['id'] for x in cond_and_ther['Conditions']]
list_of_therapies_ids = [x['id'] for x in cond_and_ther['Therapies']]

# and execute
full_patients_dict = generate_full_patients(patients_dict, list_of_conditions_ids, list_of_therapies_ids)
full_patients_dict
# Out:
# {'Patients': [{'id': 'pat_0',
#    'name': 'Piera',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2007, 6, 12),
#      'cured': None,
#      'kind': 'cond_18'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2009, 3, 5),
#      'end': datetime.date(2019, 8, 28),
#      'condition': 'c1',
#      'therapy': 'ther_52',
#      'successful': 63},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 10, 13),
#      'end': datetime.date(2019, 10, 28),
#      'condition': 'c1',
#      'therapy': 'ther_50',
#      'successful': 49},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 11, 3),
#      'end': datetime.date(2019, 11, 9),
#      'condition': 'c1',
#      'therapy': 'ther_46',
#      'successful': 44}]},
#   {'id': 'pat_1',
#    'name': 'Gianluigi',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2006, 4, 4),
#      'cured': None,
#      'kind': 'cond_35'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2007, 4, 25),
#      'cured': None,
#      'kind': 'cond_149'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2018, 2, 10),
#      'end': datetime.date(2018, 6, 27),
#      'condition': 'c1',
#      'therapy': 'ther_4',
#      'successful': 50},
#     {'id': 'c1_t2',
#      'start': datetime.date(2018, 10, 5),
#      'end': datetime.date(2019, 6, 18),
#      'condition': 'c1',
#      'therapy': 'ther_24',
#      'successful': 32},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 9, 9),
#      'end': datetime.date(2019, 9, 9),
#      'condition': 'c1',
#      'therapy': 'ther_28',
#      'successful': 61},
#     {'id': 'c1_t4',
#      'start': datetime.date(2019, 10, 30),
#      'end': datetime.date(2019, 11, 2),
#      'condition': 'c1',
#      'therapy': 'ther_45',
#      'successful': 20},
#     {'id': 'c2_t1',
#      'start': datetime.date(2012, 5, 31),
#      'end': datetime.date(2013, 4, 13),
#      'condition': 'c2',
#      'therapy': 'ther_37',
#      'successful': 53},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 11, 3),
#      'end': datetime.date(2019, 12, 5),
#      'condition': 'c2',
#      'therapy': 'ther_57',
#      'successful': 1},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 12, 5),
#      'end': datetime.date(2019, 12, 11),
#      'condition': 'c2',
#      'therapy': 'ther_36',
#      'successful': 9}]},
#   {'id': 'pat_2',
#    'name': 'Walter',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2002, 8, 14),
#      'cured': None,
#      'kind': 'cond_99'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 4, 8),
#      'cured': None,
#      'kind': 'cond_170'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 8, 25),
#      'cured': datetime.date(2019, 4, 29),
#      'kind': 'cond_194'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 11, 6),
#      'cured': None,
#      'kind': 'cond_218'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 12, 17),
#      'cured': datetime.date(2019, 12, 13),
#      'kind': 'cond_223'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2014, 8, 29),
#      'end': datetime.date(2016, 1, 14),
#      'condition': 'c1',
#      'therapy': 'ther_47',
#      'successful': 18},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 5, 31),
#      'end': datetime.date(2019, 10, 22),
#      'condition': 'c1',
#      'therapy': 'ther_58',
#      'successful': 57},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 11, 18),
#      'end': datetime.date(2019, 12, 6),
#      'condition': 'c1',
#      'therapy': 'ther_17',
#      'successful': 23},
#     {'id': 'c2_t1',
#      'start': datetime.date(2016, 5, 29),
#      'end': datetime.date(2018, 9, 13),
#      'condition': 'c2',
#      'therapy': 'ther_2',
#      'successful': 71},
#     {'id': 'c3_t1',
#      'start': datetime.date(2012, 3, 26),
#      'end': datetime.date(2013, 1, 27),
#      'condition': 'c3',
#      'therapy': 'ther_22',
#      'successful': 60},
#     {'id': 'c3_t2',
#      'start': datetime.date(2016, 10, 3),
#      'end': datetime.date(2019, 4, 29),
#      'condition': 'c3',
#      'therapy': 'ther_59',
#      'successful': 89},
#     {'id': 'c4_t1',
#      'start': datetime.date(2018, 6, 19),
#      'end': datetime.date(2018, 11, 29),
#      'condition': 'c4',
#      'therapy': 'ther_12',
#      'successful': 64},
#     {'id': 'c4_t2',
#      'start': datetime.date(2019, 10, 18),
#      'end': datetime.date(2019, 12, 16),
#      'condition': 'c4',
#      'therapy': 'ther_24',
#      'successful': 61},
#     {'id': 'c5_t1',
#      'start': datetime.date(2012, 4, 11),
#      'end': datetime.date(2019, 8, 28),
#      'condition': 'c5',
#      'therapy': 'ther_30',
#      'successful': 22},
#     {'id': 'c5_t2',
#      'start': datetime.date(2019, 10, 26),
#      'end': datetime.date(2019, 12, 13),
#      'condition': 'c5',
#      'therapy': 'ther_13',
#      'successful': 88}]},
#   {'id': 'pat_3',
#    'name': 'Nicholas',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2003, 1, 23),
#      'cured': None,
#      'kind': 'cond_60'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2003, 8, 31),
#      'cured': datetime.date(2011, 6, 9),
#      'kind': 'cond_247'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2008, 11, 22),
#      'cured': None,
#      'kind': 'cond_105'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 1, 17),
#      'cured': datetime.date(2019, 2, 3),
#      'kind': 'cond_250'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2006, 8, 4),
#      'end': datetime.date(2011, 10, 16),
#      'condition': 'c1',
#      'therapy': 'ther_43',
#      'successful': 6},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 7, 25),
#      'end': datetime.date(2019, 12, 12),
#      'condition': 'c1',
#      'therapy': 'ther_8',
#      'successful': 20},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 12, 19),
#      'end': datetime.date(2019, 12, 28),
#      'condition': 'c1',
#      'therapy': 'ther_40',
#      'successful': 39},
#     {'id': 'c1_t4',
#      'start': datetime.date(2019, 12, 29),
#      'end': datetime.date(2019, 12, 29),
#      'condition': 'c1',
#      'therapy': 'ther_59',
#      'successful': 26},
#     {'id': 'c2_t1',
#      'start': datetime.date(2004, 4, 2),
#      'end': datetime.date(2011, 6, 9),
#      'condition': 'c2',
#      'therapy': 'ther_64',
#      'successful': 79},
#     {'id': 'c3_t1',
#      'start': datetime.date(2018, 5, 11),
#      'end': datetime.date(2018, 8, 19),
#      'condition': 'c3',
#      'therapy': 'ther_13',
#      'successful': 42},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 4, 3),
#      'end': datetime.date(2019, 12, 10),
#      'condition': 'c3',
#      'therapy': 'ther_28',
#      'successful': 17},
#     {'id': 'c4_t1',
#      'start': datetime.date(2016, 12, 14),
#      'end': datetime.date(2018, 4, 19),
#      'condition': 'c4',
#      'therapy': 'ther_17',
#      'successful': 5},
#     {'id': 'c4_t2',
#      'start': datetime.date(2018, 10, 9),
#      'end': datetime.date(2019, 2, 3),
#      'condition': 'c4',
#      'therapy': 'ther_49',
#      'successful': 79}]},
#   {'id': 'pat_4',
#    'name': 'Elisa',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2000, 7, 31),
#      'cured': None,
#      'kind': 'cond_39'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2000, 8, 19),
#      'cured': None,
#      'kind': 'cond_177'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2004, 6, 12),
#      'cured': datetime.date(2019, 3, 17),
#      'kind': 'cond_249'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2007, 5, 26),
#      'cured': None,
#      'kind': 'cond_280'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2005, 9, 14),
#      'end': datetime.date(2019, 11, 20),
#      'condition': 'c1',
#      'therapy': 'ther_19',
#      'successful': 6},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 12, 13),
#      'end': datetime.date(2019, 12, 29),
#      'condition': 'c1',
#      'therapy': 'ther_31',
#      'successful': 67},
#     {'id': 'c2_t1',
#      'start': datetime.date(2017, 1, 16),
#      'end': datetime.date(2019, 12, 26),
#      'condition': 'c2',
#      'therapy': 'ther_54',
#      'successful': 5},
#     {'id': 'c3_t1',
#      'start': datetime.date(2016, 4, 26),
#      'end': datetime.date(2019, 3, 17),
#      'condition': 'c3',
#      'therapy': 'ther_44',
#      'successful': 92},
#     {'id': 'c4_t1',
#      'start': datetime.date(2019, 8, 14),
#      'end': datetime.date(2019, 11, 16),
#      'condition': 'c4',
#      'therapy': 'ther_24',
#      'successful': 40}]},
#   {'id': 'pat_5',
#    'name': 'Christian',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2004, 6, 10),
#      'cured': datetime.date(2019, 4, 10),
#      'kind': 'cond_302'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2005, 4, 14),
#      'cured': None,
#      'kind': 'cond_101'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2007, 6, 1),
#      'cured': datetime.date(2019, 12, 14),
#      'kind': 'cond_121'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2008, 8, 10),
#      'cured': datetime.date(2018, 12, 25),
#      'kind': 'cond_300'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2005, 8, 27),
#      'end': datetime.date(2012, 4, 9),
#      'condition': 'c1',
#      'therapy': 'ther_5',
#      'successful': 49},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 2, 5),
#      'end': datetime.date(2019, 4, 10),
#      'condition': 'c1',
#      'therapy': 'ther_45',
#      'successful': 95},
#     {'id': 'c2_t1',
#      'start': datetime.date(2008, 7, 27),
#      'end': datetime.date(2018, 12, 27),
#      'condition': 'c2',
#      'therapy': 'ther_1',
#      'successful': 48},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 7, 14),
#      'end': datetime.date(2019, 8, 9),
#      'condition': 'c2',
#      'therapy': 'ther_4',
#      'successful': 6},
#     {'id': 'c3_t1',
#      'start': datetime.date(2016, 6, 22),
#      'end': datetime.date(2019, 2, 11),
#      'condition': 'c3',
#      'therapy': 'ther_53',
#      'successful': 19},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 8, 7),
#      'end': datetime.date(2019, 12, 14),
#      'condition': 'c3',
#      'therapy': 'ther_65',
#      'successful': 86},
#     {'id': 'c4_t1',
#      'start': datetime.date(2014, 8, 24),
#      'end': datetime.date(2015, 6, 5),
#      'condition': 'c4',
#      'therapy': 'ther_37',
#      'successful': 46},
#     {'id': 'c4_t2',
#      'start': datetime.date(2018, 6, 29),
#      'end': datetime.date(2018, 12, 25),
#      'condition': 'c4',
#      'therapy': 'ther_61',
#      'successful': 76}]},
#   {'id': 'pat_6',
#    'name': 'Ezio',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2006, 1, 26),
#      'cured': datetime.date(2019, 12, 30),
#      'kind': 'cond_17'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2006, 2, 5),
#      'cured': None,
#      'kind': 'cond_191'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2008, 6, 17),
#      'cured': None,
#      'kind': 'cond_196'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2019, 8, 31),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c1',
#      'therapy': 'ther_9',
#      'successful': 47},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 12, 30),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c1',
#      'therapy': 'ther_55',
#      'successful': 80},
#     {'id': 'c2_t1',
#      'start': datetime.date(2014, 8, 12),
#      'end': datetime.date(2017, 9, 16),
#      'condition': 'c2',
#      'therapy': 'ther_22',
#      'successful': 51},
#     {'id': 'c2_t2',
#      'start': datetime.date(2018, 3, 2),
#      'end': datetime.date(2019, 9, 10),
#      'condition': 'c2',
#      'therapy': 'ther_53',
#      'successful': 28},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 12, 2),
#      'end': datetime.date(2019, 12, 19),
#      'condition': 'c2',
#      'therapy': 'ther_58',
#      'successful': 71},
#     {'id': 'c2_t4',
#      'start': datetime.date(2019, 12, 20),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c2',
#      'therapy': 'ther_34',
#      'successful': 32},
#     {'id': 'c3_t1',
#      'start': datetime.date(2012, 8, 17),
#      'end': datetime.date(2015, 12, 13),
#      'condition': 'c3',
#      'therapy': 'ther_47',
#      'successful': 20}]},
#   {'id': 'pat_7',
#    'name': 'Adele',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2007, 10, 19),
#      'cured': None,
#      'kind': 'cond_65'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2008, 12, 30),
#      'cured': None,
#      'kind': 'cond_220'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2014, 4, 16),
#      'end': datetime.date(2014, 4, 17),
#      'condition': 'c1',
#      'therapy': 'ther_7',
#      'successful': 61},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 9, 28),
#      'end': datetime.date(2017, 12, 3),
#      'condition': 'c1',
#      'therapy': 'ther_10',
#      'successful': 63},
#     {'id': 'c1_t3',
#      'start': datetime.date(2018, 7, 19),
#      'end': datetime.date(2019, 7, 1),
#      'condition': 'c1',
#      'therapy': 'ther_52',
#      'successful': 31},
#     {'id': 'c2_t1',
#      'start': datetime.date(2014, 6, 14),
#      'end': datetime.date(2016, 8, 21),
#      'condition': 'c2',
#      'therapy': 'ther_12',
#      'successful': 34}]},
#   {'id': 'pat_8',
#    'name': 'Maddalena',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2004, 11, 9),
#      'cured': datetime.date(2012, 8, 25),
#      'kind': 'cond_47'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2006, 12, 4),
#      'end': datetime.date(2012, 8, 25),
#      'condition': 'c1',
#      'therapy': 'ther_34',
#      'successful': 98}]},
#   {'id': 'pat_9',
#    'name': 'Giulia',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2004, 1, 21),
#      'cured': datetime.date(2019, 12, 19),
#      'kind': 'cond_209'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2006, 1, 8),
#      'cured': None,
#      'kind': 'cond_78'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2016, 7, 25),
#      'end': datetime.date(2019, 8, 18),
#      'condition': 'c1',
#      'therapy': 'ther_5',
#      'successful': 61},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 11, 7),
#      'end': datetime.date(2019, 11, 26),
#      'condition': 'c1',
#      'therapy': 'ther_55',
#      'successful': 50},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 12, 10),
#      'end': datetime.date(2019, 12, 19),
#      'condition': 'c1',
#      'therapy': 'ther_41',
#      'successful': 93},
#     {'id': 'c2_t1',
#      'start': datetime.date(2006, 8, 23),
#      'end': datetime.date(2007, 1, 16),
#      'condition': 'c2',
#      'therapy': 'ther_14',
#      'successful': 74}]},
#   {'id': 'pat_10',
#    'name': 'Paolo',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2000, 8, 2),
#      'cured': datetime.date(2019, 4, 24),
#      'kind': 'cond_4'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2008, 11, 3),
#      'cured': None,
#      'kind': 'cond_182'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 8, 6),
#      'cured': None,
#      'kind': 'cond_128'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 10, 8),
#      'cured': datetime.date(2019, 8, 8),
#      'kind': 'cond_96'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2012, 8, 2),
#      'end': datetime.date(2015, 11, 30),
#      'condition': 'c1',
#      'therapy': 'ther_36',
#      'successful': 14},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 12, 13),
#      'end': datetime.date(2019, 4, 24),
#      'condition': 'c1',
#      'therapy': 'ther_4',
#      'successful': 85},
#     {'id': 'c2_t1',
#      'start': datetime.date(2013, 11, 30),
#      'end': datetime.date(2016, 8, 10),
#      'condition': 'c2',
#      'therapy': 'ther_34',
#      'successful': 64},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 5, 19),
#      'end': datetime.date(2019, 7, 3),
#      'condition': 'c2',
#      'therapy': 'ther_53',
#      'successful': 24},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 12, 5),
#      'end': datetime.date(2019, 12, 19),
#      'condition': 'c2',
#      'therapy': 'ther_46',
#      'successful': 66},
#     {'id': 'c3_t1',
#      'start': datetime.date(2013, 8, 30),
#      'end': datetime.date(2016, 10, 13),
#      'condition': 'c3',
#      'therapy': 'ther_62',
#      'successful': 60},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 11, 10),
#      'end': datetime.date(2019, 11, 24),
#      'condition': 'c3',
#      'therapy': 'ther_57',
#      'successful': 29},
#     {'id': 'c4_t1',
#      'start': datetime.date(2017, 11, 8),
#      'end': datetime.date(2019, 8, 8),
#      'condition': 'c4',
#      'therapy': 'ther_45',
#      'successful': 89}]},
#   {'id': 'pat_11',
#    'name': 'Stella',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2007, 10, 13),
#      'cured': datetime.date(2019, 3, 1),
#      'kind': 'cond_132'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2012, 5, 16),
#      'end': datetime.date(2019, 3, 1),
#      'condition': 'c1',
#      'therapy': 'ther_66',
#      'successful': 85}]},
#   {'id': 'pat_12',
#    'name': 'Loredana',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2002, 2, 20),
#      'cured': datetime.date(2011, 12, 13),
#      'kind': 'cond_156'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2006, 4, 18),
#      'cured': datetime.date(2019, 12, 4),
#      'kind': 'cond_106'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2008, 9, 17),
#      'cured': None,
#      'kind': 'cond_121'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 10, 13),
#      'cured': datetime.date(2014, 5, 13),
#      'kind': 'cond_84'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 12, 2),
#      'cured': None,
#      'kind': 'cond_271'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2008, 3, 9),
#      'end': datetime.date(2011, 12, 13),
#      'condition': 'c1',
#      'therapy': 'ther_27',
#      'successful': 86},
#     {'id': 'c2_t1',
#      'start': datetime.date(2009, 9, 5),
#      'end': datetime.date(2017, 2, 4),
#      'condition': 'c2',
#      'therapy': 'ther_11',
#      'successful': 23},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 3, 31),
#      'end': datetime.date(2019, 7, 27),
#      'condition': 'c2',
#      'therapy': 'ther_16',
#      'successful': 67},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 11, 13),
#      'end': datetime.date(2019, 12, 4),
#      'condition': 'c2',
#      'therapy': 'ther_22',
#      'successful': 79},
#     {'id': 'c3_t1',
#      'start': datetime.date(2017, 8, 28),
#      'end': datetime.date(2018, 8, 19),
#      'condition': 'c3',
#      'therapy': 'ther_51',
#      'successful': 40},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 10, 26),
#      'end': datetime.date(2019, 12, 16),
#      'condition': 'c3',
#      'therapy': 'ther_45',
#      'successful': 75},
#     {'id': 'c3_t3',
#      'start': datetime.date(2019, 12, 28),
#      'end': datetime.date(2019, 12, 29),
#      'condition': 'c3',
#      'therapy': 'ther_54',
#      'successful': 68},
#     {'id': 'c4_t1',
#      'start': datetime.date(2011, 8, 16),
#      'end': datetime.date(2014, 5, 13),
#      'condition': 'c4',
#      'therapy': 'ther_35',
#      'successful': 85},
#     {'id': 'c5_t1',
#      'start': datetime.date(2013, 5, 8),
#      'end': datetime.date(2016, 7, 20),
#      'condition': 'c5',
#      'therapy': 'ther_15',
#      'successful': 36}]},
#   {'id': 'pat_13',
#    'name': 'Giusi',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2008, 1, 31),
#      'cured': None,
#      'kind': 'cond_297'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2011, 10, 23),
#      'end': datetime.date(2012, 7, 22),
#      'condition': 'c1',
#      'therapy': 'ther_26',
#      'successful': 26},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 6, 8),
#      'end': datetime.date(2017, 8, 4),
#      'condition': 'c1',
#      'therapy': 'ther_33',
#      'successful': 41},
#     {'id': 'c1_t3',
#      'start': datetime.date(2018, 11, 1),
#      'end': datetime.date(2018, 11, 14),
#      'condition': 'c1',
#      'therapy': 'ther_57',
#      'successful': 34},
#     {'id': 'c1_t4',
#      'start': datetime.date(2019, 9, 7),
#      'end': datetime.date(2019, 10, 31),
#      'condition': 'c1',
#      'therapy': 'ther_59',
#      'successful': 63}]},
#   {'id': 'pat_14',
#    'name': 'Simo',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2002, 3, 28),
#      'cured': None,
#      'kind': 'cond_200'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2003, 3, 30),
#      'cured': datetime.date(2012, 5, 31),
#      'kind': 'cond_198'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2014, 11, 23),
#      'end': datetime.date(2016, 7, 20),
#      'condition': 'c1',
#      'therapy': 'ther_45',
#      'successful': 1},
#     {'id': 'c2_t1',
#      'start': datetime.date(2004, 10, 11),
#      'end': datetime.date(2012, 5, 31),
#      'condition': 'c2',
#      'therapy': 'ther_37',
#      'successful': 80}]},
#   {'id': 'pat_15',
#    'name': 'Serena',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2001, 5, 1),
#      'cured': datetime.date(2018, 12, 9),
#      'kind': 'cond_39'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2006, 3, 16),
#      'cured': None,
#      'kind': 'cond_303'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2007, 9, 11),
#      'cured': None,
#      'kind': 'cond_296'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2010, 6, 29),
#      'end': datetime.date(2017, 3, 7),
#      'condition': 'c1',
#      'therapy': 'ther_65',
#      'successful': 6},
#     {'id': 'c1_t2',
#      'start': datetime.date(2018, 2, 27),
#      'end': datetime.date(2018, 12, 9),
#      'condition': 'c1',
#      'therapy': 'ther_63',
#      'successful': 90},
#     {'id': 'c2_t1',
#      'start': datetime.date(2013, 2, 18),
#      'end': datetime.date(2015, 7, 6),
#      'condition': 'c2',
#      'therapy': 'ther_1',
#      'successful': 54},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 11, 7),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c2',
#      'therapy': 'ther_33',
#      'successful': 18},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 12, 31),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c2',
#      'therapy': 'ther_21',
#      'successful': 28},
#     {'id': 'c3_t1',
#      'start': datetime.date(2016, 9, 21),
#      'end': datetime.date(2018, 9, 2),
#      'condition': 'c3',
#      'therapy': 'ther_49',
#      'successful': 11},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 3, 20),
#      'end': datetime.date(2019, 5, 25),
#      'condition': 'c3',
#      'therapy': 'ther_41',
#      'successful': 47}]},
#   {'id': 'pat_16',
#    'name': 'Gio',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2008, 9, 15),
#      'cured': datetime.date(2019, 9, 12),
#      'kind': 'cond_114'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2015, 4, 10),
#      'end': datetime.date(2017, 7, 13),
#      'condition': 'c1',
#      'therapy': 'ther_30',
#      'successful': 50},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 8, 8),
#      'end': datetime.date(2019, 9, 12),
#      'condition': 'c1',
#      'therapy': 'ther_27',
#      'successful': 87}]},
#   {'id': 'pat_17',
#    'name': 'Rachele',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2009, 9, 10),
#      'cured': None,
#      'kind': 'cond_11'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 11, 8),
#      'cured': datetime.date(2019, 9, 28),
#      'kind': 'cond_155'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2012, 9, 16),
#      'end': datetime.date(2018, 3, 16),
#      'condition': 'c1',
#      'therapy': 'ther_22',
#      'successful': 30},
#     {'id': 'c2_t1',
#      'start': datetime.date(2010, 2, 9),
#      'end': datetime.date(2019, 9, 28),
#      'condition': 'c2',
#      'therapy': 'ther_57',
#      'successful': 93}]},
#   {'id': 'pat_18',
#    'name': 'Alfio',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2000, 6, 1),
#      'cured': datetime.date(2019, 6, 6),
#      'kind': 'cond_293'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 11, 2),
#      'cured': datetime.date(2018, 10, 4),
#      'kind': 'cond_215'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2007, 9, 11),
#      'end': datetime.date(2012, 2, 21),
#      'condition': 'c1',
#      'therapy': 'ther_66',
#      'successful': 3},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 3, 10),
#      'end': datetime.date(2017, 3, 28),
#      'condition': 'c1',
#      'therapy': 'ther_24',
#      'successful': 60},
#     {'id': 'c1_t3',
#      'start': datetime.date(2017, 10, 21),
#      'end': datetime.date(2019, 6, 6),
#      'condition': 'c1',
#      'therapy': 'ther_51',
#      'successful': 86},
#     {'id': 'c2_t1',
#      'start': datetime.date(2013, 10, 7),
#      'end': datetime.date(2018, 10, 4),
#      'condition': 'c2',
#      'therapy': 'ther_1',
#      'successful': 92}]},
#   {'id': 'pat_19',
#    'name': 'Alessia',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2005, 11, 28),
#      'cured': None,
#      'kind': 'cond_223'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 5, 23),
#      'cured': datetime.date(2019, 12, 23),
#      'kind': 'cond_156'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2010, 5, 16),
#      'end': datetime.date(2017, 7, 27),
#      'condition': 'c1',
#      'therapy': 'ther_13',
#      'successful': 7},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 12, 30),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c1',
#      'therapy': 'ther_64',
#      'successful': 68},
#     {'id': 'c2_t1',
#      'start': datetime.date(2011, 2, 14),
#      'end': datetime.date(2019, 2, 17),
#      'condition': 'c2',
#      'therapy': 'ther_43',
#      'successful': 30},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 12, 22),
#      'end': datetime.date(2019, 12, 23),
#      'condition': 'c2',
#      'therapy': 'ther_34',
#      'successful': 86}]},
#   {'id': 'pat_20',
#    'name': 'Barbara',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2008, 2, 5),
#      'cured': datetime.date(2019, 5, 19),
#      'kind': 'cond_287'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2017, 12, 13),
#      'end': datetime.date(2019, 5, 19),
#      'condition': 'c1',
#      'therapy': 'ther_29',
#      'successful': 80}]},
#   {'id': 'pat_21',
#    'name': 'Peppe',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2004, 8, 20),
#      'cured': datetime.date(2018, 10, 31),
#      'kind': 'cond_26'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 8, 4),
#      'cured': None,
#      'kind': 'cond_138'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 8, 6),
#      'cured': datetime.date(2019, 4, 30),
#      'kind': 'cond_161'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 9, 11),
#      'cured': datetime.date(2014, 4, 15),
#      'kind': 'cond_4'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 9, 25),
#      'cured': datetime.date(2013, 4, 21),
#      'kind': 'cond_48'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2017, 10, 24),
#      'end': datetime.date(2018, 10, 31),
#      'condition': 'c1',
#      'therapy': 'ther_35',
#      'successful': 91},
#     {'id': 'c2_t1',
#      'start': datetime.date(2013, 7, 22),
#      'end': datetime.date(2018, 6, 8),
#      'condition': 'c2',
#      'therapy': 'ther_12',
#      'successful': 0},
#     {'id': 'c3_t1',
#      'start': datetime.date(2018, 6, 10),
#      'end': datetime.date(2019, 4, 30),
#      'condition': 'c3',
#      'therapy': 'ther_0',
#      'successful': 93},
#     {'id': 'c4_t1',
#      'start': datetime.date(2010, 11, 5),
#      'end': datetime.date(2014, 4, 15),
#      'condition': 'c4',
#      'therapy': 'ther_18',
#      'successful': 97},
#     {'id': 'c5_t1',
#      'start': datetime.date(2013, 3, 4),
#      'end': datetime.date(2013, 4, 21),
#      'condition': 'c5',
#      'therapy': 'ther_19',
#      'successful': 97}]},
#   {'id': 'pat_22',
#    'name': 'Fabio',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2005, 3, 25),
#      'cured': datetime.date(2019, 12, 30),
#      'kind': 'cond_205'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2008, 4, 23),
#      'cured': datetime.date(2019, 12, 31),
#      'kind': 'cond_95'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2008, 7, 4),
#      'cured': None,
#      'kind': 'cond_37'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2010, 1, 16),
#      'end': datetime.date(2013, 9, 4),
#      'condition': 'c1',
#      'therapy': 'ther_57',
#      'successful': 6},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 9, 27),
#      'end': datetime.date(2018, 8, 10),
#      'condition': 'c1',
#      'therapy': 'ther_4',
#      'successful': 0},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 11, 21),
#      'end': datetime.date(2019, 12, 29),
#      'condition': 'c1',
#      'therapy': 'ther_44',
#      'successful': 57},
#     {'id': 'c1_t4',
#      'start': datetime.date(2019, 12, 29),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c1',
#      'therapy': 'ther_13',
#      'successful': 92},
#     {'id': 'c2_t1',
#      'start': datetime.date(2014, 6, 12),
#      'end': datetime.date(2017, 5, 26),
#      'condition': 'c2',
#      'therapy': 'ther_32',
#      'successful': 26},
#     {'id': 'c2_t2',
#      'start': datetime.date(2017, 12, 13),
#      'end': datetime.date(2018, 4, 18),
#      'condition': 'c2',
#      'therapy': 'ther_64',
#      'successful': 70},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 11, 20),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c2',
#      'therapy': 'ther_26',
#      'successful': 84},
#     {'id': 'c3_t1',
#      'start': datetime.date(2014, 1, 25),
#      'end': datetime.date(2018, 8, 3),
#      'condition': 'c3',
#      'therapy': 'ther_25',
#      'successful': 40}]},
#   {'id': 'pat_23',
#    'name': 'Saverio',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2006, 12, 2),
#      'cured': datetime.date(2019, 12, 15),
#      'kind': 'cond_150'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2007, 2, 2),
#      'cured': datetime.date(2012, 9, 6),
#      'kind': 'cond_125'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 7, 5),
#      'cured': datetime.date(2019, 12, 28),
#      'kind': 'cond_275'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 10, 21),
#      'cured': None,
#      'kind': 'cond_124'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 12, 8),
#      'cured': datetime.date(2019, 9, 17),
#      'kind': 'cond_41'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2017, 6, 19),
#      'end': datetime.date(2019, 6, 17),
#      'condition': 'c1',
#      'therapy': 'ther_5',
#      'successful': 59},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 7, 25),
#      'end': datetime.date(2019, 12, 9),
#      'condition': 'c1',
#      'therapy': 'ther_19',
#      'successful': 52},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 12, 11),
#      'end': datetime.date(2019, 12, 15),
#      'condition': 'c1',
#      'therapy': 'ther_66',
#      'successful': 80},
#     {'id': 'c2_t1',
#      'start': datetime.date(2008, 10, 12),
#      'end': datetime.date(2012, 9, 6),
#      'condition': 'c2',
#      'therapy': 'ther_12',
#      'successful': 79},
#     {'id': 'c3_t1',
#      'start': datetime.date(2013, 12, 19),
#      'end': datetime.date(2015, 7, 12),
#      'condition': 'c3',
#      'therapy': 'ther_64',
#      'successful': 7},
#     {'id': 'c3_t2',
#      'start': datetime.date(2016, 10, 24),
#      'end': datetime.date(2017, 8, 10),
#      'condition': 'c3',
#      'therapy': 'ther_14',
#      'successful': 61},
#     {'id': 'c3_t3',
#      'start': datetime.date(2019, 6, 8),
#      'end': datetime.date(2019, 12, 28),
#      'condition': 'c3',
#      'therapy': 'ther_58',
#      'successful': 90},
#     {'id': 'c4_t1',
#      'start': datetime.date(2016, 8, 30),
#      'end': datetime.date(2017, 12, 17),
#      'condition': 'c4',
#      'therapy': 'ther_33',
#      'successful': 12},
#     {'id': 'c4_t2',
#      'start': datetime.date(2018, 8, 18),
#      'end': datetime.date(2019, 6, 2),
#      'condition': 'c4',
#      'therapy': 'ther_11',
#      'successful': 54},
#     {'id': 'c4_t3',
#      'start': datetime.date(2019, 11, 4),
#      'end': datetime.date(2019, 12, 22),
#      'condition': 'c4',
#      'therapy': 'ther_25',
#      'successful': 70},
#     {'id': 'c5_t1',
#      'start': datetime.date(2018, 9, 1),
#      'end': datetime.date(2019, 4, 15),
#      'condition': 'c5',
#      'therapy': 'ther_43',
#      'successful': 63},
#     {'id': 'c5_t2',
#      'start': datetime.date(2019, 9, 3),
#      'end': datetime.date(2019, 9, 17),
#      'condition': 'c5',
#      'therapy': 'ther_9',
#      'successful': 89}]},
#   {'id': 'pat_24',
#    'name': 'Martina',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2007, 12, 3),
#      'cured': None,
#      'kind': 'cond_44'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2019, 12, 23),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c1',
#      'therapy': 'ther_23',
#      'successful': 50}]},
#   {'id': 'pat_25',
#    'name': 'Luciano',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2000, 12, 3),
#      'cured': datetime.date(2015, 8, 19),
#      'kind': 'cond_155'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2005, 10, 18),
#      'cured': None,
#      'kind': 'cond_62'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2006, 4, 12),
#      'cured': datetime.date(2016, 1, 12),
#      'kind': 'cond_184'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2006, 7, 12),
#      'cured': None,
#      'kind': 'cond_69'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2013, 12, 3),
#      'end': datetime.date(2015, 8, 19),
#      'condition': 'c1',
#      'therapy': 'ther_37',
#      'successful': 96},
#     {'id': 'c2_t1',
#      'start': datetime.date(2013, 3, 8),
#      'end': datetime.date(2019, 1, 28),
#      'condition': 'c2',
#      'therapy': 'ther_58',
#      'successful': 56},
#     {'id': 'c3_t1',
#      'start': datetime.date(2014, 4, 30),
#      'end': datetime.date(2016, 1, 12),
#      'condition': 'c3',
#      'therapy': 'ther_12',
#      'successful': 97},
#     {'id': 'c4_t1',
#      'start': datetime.date(2018, 12, 16),
#      'end': datetime.date(2019, 6, 20),
#      'condition': 'c4',
#      'therapy': 'ther_36',
#      'successful': 65},
#     {'id': 'c4_t2',
#      'start': datetime.date(2019, 12, 9),
#      'end': datetime.date(2019, 12, 20),
#      'condition': 'c4',
#      'therapy': 'ther_41',
#      'successful': 0}]},
#   {'id': 'pat_26',
#    'name': 'Tania',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2003, 2, 27),
#      'cured': None,
#      'kind': 'cond_141'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2019, 5, 6),
#      'end': datetime.date(2019, 12, 14),
#      'condition': 'c1',
#      'therapy': 'ther_11',
#      'successful': 11}]},
#   {'id': 'pat_27',
#    'name': 'Jacopo',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2005, 11, 28),
#      'cured': None,
#      'kind': 'cond_116'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2006, 2, 9),
#      'cured': None,
#      'kind': 'cond_146'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2011, 8, 28),
#      'end': datetime.date(2015, 12, 15),
#      'condition': 'c1',
#      'therapy': 'ther_20',
#      'successful': 33},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 10, 30),
#      'end': datetime.date(2018, 7, 10),
#      'condition': 'c1',
#      'therapy': 'ther_40',
#      'successful': 45},
#     {'id': 'c1_t3',
#      'start': datetime.date(2018, 7, 12),
#      'end': datetime.date(2019, 12, 25),
#      'condition': 'c1',
#      'therapy': 'ther_52',
#      'successful': 21},
#     {'id': 'c1_t4',
#      'start': datetime.date(2019, 12, 29),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c1',
#      'therapy': 'ther_14',
#      'successful': 23},
#     {'id': 'c2_t1',
#      'start': datetime.date(2019, 12, 19),
#      'end': datetime.date(2019, 12, 22),
#      'condition': 'c2',
#      'therapy': 'ther_48',
#      'successful': 60},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 12, 22),
#      'end': datetime.date(2019, 12, 22),
#      'condition': 'c2',
#      'therapy': 'ther_23',
#      'successful': 41},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 12, 22),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c2',
#      'therapy': 'ther_30',
#      'successful': 17}]},
#   {'id': 'pat_28',
#    'name': 'Donato',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2009, 6, 27),
#      'cured': None,
#      'kind': 'cond_257'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 8, 31),
#      'cured': None,
#      'kind': 'cond_100'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 9, 19),
#      'cured': datetime.date(2019, 12, 22),
#      'kind': 'cond_28'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 12, 19),
#      'cured': datetime.date(2019, 3, 30),
#      'kind': 'cond_155'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2015, 8, 8),
#      'end': datetime.date(2018, 3, 7),
#      'condition': 'c1',
#      'therapy': 'ther_26',
#      'successful': 30},
#     {'id': 'c2_t1',
#      'start': datetime.date(2010, 4, 27),
#      'end': datetime.date(2019, 12, 7),
#      'condition': 'c2',
#      'therapy': 'ther_30',
#      'successful': 69},
#     {'id': 'c2_t2',
#      'start': datetime.date(2019, 12, 24),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c2',
#      'therapy': 'ther_38',
#      'successful': 72},
#     {'id': 'c3_t1',
#      'start': datetime.date(2019, 6, 21),
#      'end': datetime.date(2019, 11, 20),
#      'condition': 'c3',
#      'therapy': 'ther_14',
#      'successful': 18},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 12, 4),
#      'end': datetime.date(2019, 12, 22),
#      'condition': 'c3',
#      'therapy': 'ther_4',
#      'successful': 95},
#     {'id': 'c4_t1',
#      'start': datetime.date(2017, 11, 11),
#      'end': datetime.date(2019, 3, 30),
#      'condition': 'c4',
#      'therapy': 'ther_58',
#      'successful': 84}]},
#   {'id': 'pat_29',
#    'name': 'Niccolò',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2001, 2, 9),
#      'cured': datetime.date(2019, 11, 30),
#      'kind': 'cond_41'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 1, 24),
#      'cured': datetime.date(2019, 12, 25),
#      'kind': 'cond_70'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 12, 18),
#      'cured': datetime.date(2018, 4, 27),
#      'kind': 'cond_118'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 12, 21),
#      'cured': datetime.date(2015, 12, 28),
#      'kind': 'cond_5'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2019, 3, 5),
#      'end': datetime.date(2019, 9, 19),
#      'condition': 'c1',
#      'therapy': 'ther_13',
#      'successful': 15},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 10, 22),
#      'end': datetime.date(2019, 11, 30),
#      'condition': 'c1',
#      'therapy': 'ther_28',
#      'successful': 88},
#     {'id': 'c2_t1',
#      'start': datetime.date(2016, 3, 5),
#      'end': datetime.date(2017, 11, 9),
#      'condition': 'c2',
#      'therapy': 'ther_43',
#      'successful': 38},
#     {'id': 'c2_t2',
#      'start': datetime.date(2018, 12, 4),
#      'end': datetime.date(2019, 6, 27),
#      'condition': 'c2',
#      'therapy': 'ther_13',
#      'successful': 8},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 8, 6),
#      'end': datetime.date(2019, 9, 10),
#      'condition': 'c2',
#      'therapy': 'ther_17',
#      'successful': 31},
#     {'id': 'c2_t4',
#      'start': datetime.date(2019, 12, 25),
#      'end': datetime.date(2019, 12, 25),
#      'condition': 'c2',
#      'therapy': 'ther_8',
#      'successful': 97},
#     {'id': 'c3_t1',
#      'start': datetime.date(2015, 12, 29),
#      'end': datetime.date(2018, 4, 27),
#      'condition': 'c3',
#      'therapy': 'ther_11',
#      'successful': 79},
#     {'id': 'c4_t1',
#      'start': datetime.date(2015, 7, 13),
#      'end': datetime.date(2015, 12, 28),
#      'condition': 'c4',
#      'therapy': 'ther_8',
#      'successful': 93}]},
#   {'id': 'pat_30',
#    'name': 'Gianna',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2004, 9, 25),
#      'cured': datetime.date(2019, 1, 7),
#      'kind': 'cond_61'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2013, 4, 12),
#      'end': datetime.date(2016, 8, 20),
#      'condition': 'c1',
#      'therapy': 'ther_43',
#      'successful': 49},
#     {'id': 'c1_t2',
#      'start': datetime.date(2018, 1, 4),
#      'end': datetime.date(2019, 1, 7),
#      'condition': 'c1',
#      'therapy': 'ther_57',
#      'successful': 97}]},
#   {'id': 'pat_31',
#    'name': 'Tonino',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2001, 7, 13),
#      'cured': datetime.date(2019, 12, 11),
#      'kind': 'cond_230'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2008, 10, 24),
#      'cured': datetime.date(2019, 11, 18),
#      'kind': 'cond_299'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 5, 21),
#      'cured': datetime.date(2019, 12, 29),
#      'kind': 'cond_148'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 8, 9),
#      'cured': datetime.date(2016, 4, 22),
#      'kind': 'cond_115'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 12, 19),
#      'cured': datetime.date(2019, 4, 16),
#      'kind': 'cond_210'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2006, 10, 28),
#      'end': datetime.date(2018, 6, 2),
#      'condition': 'c1',
#      'therapy': 'ther_61',
#      'successful': 17},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 6, 22),
#      'end': datetime.date(2019, 8, 24),
#      'condition': 'c1',
#      'therapy': 'ther_41',
#      'successful': 48},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 11, 5),
#      'end': datetime.date(2019, 12, 11),
#      'condition': 'c1',
#      'therapy': 'ther_1',
#      'successful': 87},
#     {'id': 'c2_t1',
#      'start': datetime.date(2019, 4, 1),
#      'end': datetime.date(2019, 11, 18),
#      'condition': 'c2',
#      'therapy': 'ther_33',
#      'successful': 82},
#     {'id': 'c3_t1',
#      'start': datetime.date(2013, 3, 24),
#      'end': datetime.date(2013, 5, 5),
#      'condition': 'c3',
#      'therapy': 'ther_3',
#      'successful': 6},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 5, 21),
#      'end': datetime.date(2019, 8, 16),
#      'condition': 'c3',
#      'therapy': 'ther_29',
#      'successful': 0},
#     {'id': 'c3_t3',
#      'start': datetime.date(2019, 9, 12),
#      'end': datetime.date(2019, 12, 29),
#      'condition': 'c3',
#      'therapy': 'ther_17',
#      'successful': 97},
#     {'id': 'c4_t1',
#      'start': datetime.date(2011, 1, 26),
#      'end': datetime.date(2016, 4, 22),
#      'condition': 'c4',
#      'therapy': 'ther_52',
#      'successful': 87},
#     {'id': 'c5_t1',
#      'start': datetime.date(2012, 10, 14),
#      'end': datetime.date(2017, 7, 8),
#      'condition': 'c5',
#      'therapy': 'ther_15',
#      'successful': 3},
#     {'id': 'c5_t2',
#      'start': datetime.date(2018, 5, 3),
#      'end': datetime.date(2019, 4, 16),
#      'condition': 'c5',
#      'therapy': 'ther_46',
#      'successful': 84}]},
#   {'id': 'pat_32',
#    'name': 'Sara',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2008, 5, 2),
#      'cured': datetime.date(2019, 4, 24),
#      'kind': 'cond_78'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 7, 27),
#      'cured': None,
#      'kind': 'cond_98'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 7, 31),
#      'cured': None,
#      'kind': 'cond_38'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 11, 25),
#      'cured': None,
#      'kind': 'cond_118'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 11, 26),
#      'cured': datetime.date(2019, 12, 31),
#      'kind': 'cond_54'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2012, 11, 11),
#      'end': datetime.date(2017, 6, 28),
#      'condition': 'c1',
#      'therapy': 'ther_30',
#      'successful': 63},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 2, 21),
#      'end': datetime.date(2019, 4, 24),
#      'condition': 'c1',
#      'therapy': 'ther_63',
#      'successful': 76},
#     {'id': 'c2_t1',
#      'start': datetime.date(2017, 1, 5),
#      'end': datetime.date(2019, 11, 22),
#      'condition': 'c2',
#      'therapy': 'ther_0',
#      'successful': 69},
#     {'id': 'c3_t1',
#      'start': datetime.date(2017, 7, 10),
#      'end': datetime.date(2017, 7, 27),
#      'condition': 'c3',
#      'therapy': 'ther_11',
#      'successful': 0},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 1, 24),
#      'end': datetime.date(2019, 5, 10),
#      'condition': 'c3',
#      'therapy': 'ther_50',
#      'successful': 6},
#     {'id': 'c3_t3',
#      'start': datetime.date(2019, 10, 21),
#      'end': datetime.date(2019, 11, 19),
#      'condition': 'c3',
#      'therapy': 'ther_45',
#      'successful': 32},
#     {'id': 'c4_t1',
#      'start': datetime.date(2012, 9, 26),
#      'end': datetime.date(2019, 5, 15),
#      'condition': 'c4',
#      'therapy': 'ther_60',
#      'successful': 22},
#     {'id': 'c4_t2',
#      'start': datetime.date(2019, 10, 28),
#      'end': datetime.date(2019, 12, 27),
#      'condition': 'c4',
#      'therapy': 'ther_63',
#      'successful': 34},
#     {'id': 'c4_t3',
#      'start': datetime.date(2019, 12, 28),
#      'end': datetime.date(2019, 12, 29),
#      'condition': 'c4',
#      'therapy': 'ther_2',
#      'successful': 29},
#     {'id': 'c4_t4',
#      'start': datetime.date(2019, 12, 30),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c4',
#      'therapy': 'ther_27',
#      'successful': 2},
#     {'id': 'c5_t1',
#      'start': datetime.date(2019, 11, 14),
#      'end': datetime.date(2019, 11, 23),
#      'condition': 'c5',
#      'therapy': 'ther_56',
#      'successful': 68},
#     {'id': 'c5_t2',
#      'start': datetime.date(2019, 12, 31),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c5',
#      'therapy': 'ther_7',
#      'successful': 85}]},
#   {'id': 'pat_33',
#    'name': 'Gianfranco',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2000, 1, 30),
#      'cured': datetime.date(2019, 10, 2),
#      'kind': 'cond_252'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2001, 8, 9),
#      'cured': None,
#      'kind': 'cond_104'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2004, 3, 30),
#      'cured': datetime.date(2019, 12, 30),
#      'kind': 'cond_170'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2007, 4, 21),
#      'cured': datetime.date(2019, 11, 13),
#      'kind': 'cond_90'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2018, 11, 16),
#      'end': datetime.date(2019, 10, 2),
#      'condition': 'c1',
#      'therapy': 'ther_15',
#      'successful': 89},
#     {'id': 'c2_t1',
#      'start': datetime.date(2008, 7, 7),
#      'end': datetime.date(2017, 9, 30),
#      'condition': 'c2',
#      'therapy': 'ther_38',
#      'successful': 75},
#     {'id': 'c3_t1',
#      'start': datetime.date(2008, 5, 17),
#      'end': datetime.date(2019, 4, 24),
#      'condition': 'c3',
#      'therapy': 'ther_17',
#      'successful': 65},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 10, 7),
#      'end': datetime.date(2019, 10, 17),
#      'condition': 'c3',
#      'therapy': 'ther_10',
#      'successful': 26},
#     {'id': 'c3_t3',
#      'start': datetime.date(2019, 12, 23),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c3',
#      'therapy': 'ther_24',
#      'successful': 95},
#     {'id': 'c4_t1',
#      'start': datetime.date(2009, 9, 8),
#      'end': datetime.date(2009, 12, 26),
#      'condition': 'c4',
#      'therapy': 'ther_46',
#      'successful': 0},
#     {'id': 'c4_t2',
#      'start': datetime.date(2011, 3, 20),
#      'end': datetime.date(2018, 8, 19),
#      'condition': 'c4',
#      'therapy': 'ther_56',
#      'successful': 3},
#     {'id': 'c4_t3',
#      'start': datetime.date(2018, 10, 14),
#      'end': datetime.date(2019, 10, 12),
#      'condition': 'c4',
#      'therapy': 'ther_59',
#      'successful': 25},
#     {'id': 'c4_t4',
#      'start': datetime.date(2019, 10, 27),
#      'end': datetime.date(2019, 11, 13),
#      'condition': 'c4',
#      'therapy': 'ther_60',
#      'successful': 78}]},
#   {'id': 'pat_34',
# ...
#      'therapy': 'ther_21',
#      'successful': 42},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 11, 24),
#      'end': datetime.date(2019, 12, 9),
#      'condition': 'c2',
#      'therapy': 'ther_23',
#      'successful': 9},
#     {'id': 'c2_t4',
#      'start': datetime.date(2019, 12, 14),
#      'end': datetime.date(2019, 12, 18),
#      'condition': 'c2',
#      'therapy': 'ther_22',
#      'successful': 88},
#     {'id': 'c3_t1',
#      'start': datetime.date(2012, 5, 22),
#      'end': datetime.date(2014, 5, 15),
#      'condition': 'c3',
#      'therapy': 'ther_33',
#      'successful': 32},
#     {'id': 'c3_t2',
#      'start': datetime.date(2018, 7, 27),
#      'end': datetime.date(2018, 12, 24),
#      'condition': 'c3',
#      'therapy': 'ther_9',
#      'successful': 86},
#     {'id': 'c4_t1',
#      'start': datetime.date(2012, 11, 22),
#      'end': datetime.date(2014, 2, 8),
#      'condition': 'c4',
#      'therapy': 'ther_44',
#      'successful': 71},
#     {'id': 'c4_t2',
#      'start': datetime.date(2019, 4, 18),
#      'end': datetime.date(2019, 11, 29),
#      'condition': 'c4',
#      'therapy': 'ther_8',
#      'successful': 96},
#     {'id': 'c5_t1',
#      'start': datetime.date(2014, 9, 26),
#      'end': datetime.date(2017, 8, 19),
#      'condition': 'c5',
#      'therapy': 'ther_23',
#      'successful': 1},
#     {'id': 'c5_t2',
#      'start': datetime.date(2019, 3, 9),
#      'end': datetime.date(2019, 5, 7),
#      'condition': 'c5',
#      'therapy': 'ther_36',
#      'successful': 6}]},
#   {'id': 'pat_391',
#    'name': 'Flavio',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2005, 8, 2),
#      'cured': datetime.date(2019, 6, 16),
#      'kind': 'cond_0'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2005, 8, 13),
#      'cured': datetime.date(2017, 10, 13),
#      'kind': 'cond_182'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 12, 22),
#      'cured': datetime.date(2016, 12, 23),
#      'kind': 'cond_298'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 12, 31),
#      'cured': None,
#      'kind': 'cond_127'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2016, 7, 20),
#      'end': datetime.date(2019, 6, 16),
#      'condition': 'c1',
#      'therapy': 'ther_27',
#      'successful': 96},
#     {'id': 'c2_t1',
#      'start': datetime.date(2011, 7, 14),
#      'end': datetime.date(2016, 1, 13),
#      'condition': 'c2',
#      'therapy': 'ther_21',
#      'successful': 68},
#     {'id': 'c2_t2',
#      'start': datetime.date(2017, 6, 25),
#      'end': datetime.date(2017, 10, 13),
#      'condition': 'c2',
#      'therapy': 'ther_18',
#      'successful': 79},
#     {'id': 'c3_t1',
#      'start': datetime.date(2010, 10, 30),
#      'end': datetime.date(2016, 12, 23),
#      'condition': 'c3',
#      'therapy': 'ther_26',
#      'successful': 89},
#     {'id': 'c4_t1',
#      'start': datetime.date(2010, 10, 18),
#      'end': datetime.date(2014, 12, 30),
#      'condition': 'c4',
#      'therapy': 'ther_39',
#      'successful': 17},
#     {'id': 'c4_t2',
#      'start': datetime.date(2017, 11, 16),
#      'end': datetime.date(2018, 5, 28),
#      'condition': 'c4',
#      'therapy': 'ther_1',
#      'successful': 15},
#     {'id': 'c4_t3',
#      'start': datetime.date(2018, 12, 30),
#      'end': datetime.date(2019, 11, 8),
#      'condition': 'c4',
#      'therapy': 'ther_28',
#      'successful': 25}]},
#   {'id': 'pat_392',
#    'name': 'Angela',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2008, 3, 29),
#      'cured': None,
#      'kind': 'cond_217'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2009, 3, 6),
#      'cured': None,
#      'kind': 'cond_253'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 6, 10),
#      'cured': None,
#      'kind': 'cond_136'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2012, 12, 15),
#      'end': datetime.date(2015, 5, 4),
#      'condition': 'c1',
#      'therapy': 'ther_66',
#      'successful': 51},
#     {'id': 'c1_t2',
#      'start': datetime.date(2017, 10, 16),
#      'end': datetime.date(2018, 1, 8),
#      'condition': 'c1',
#      'therapy': 'ther_12',
#      'successful': 62},
#     {'id': 'c1_t3',
#      'start': datetime.date(2018, 4, 11),
#      'end': datetime.date(2019, 5, 6),
#      'condition': 'c1',
#      'therapy': 'ther_21',
#      'successful': 70},
#     {'id': 'c1_t4',
#      'start': datetime.date(2019, 8, 4),
#      'end': datetime.date(2019, 10, 26),
#      'condition': 'c1',
#      'therapy': 'ther_47',
#      'successful': 36},
#     {'id': 'c2_t1',
#      'start': datetime.date(2019, 6, 21),
#      'end': datetime.date(2019, 8, 23),
#      'condition': 'c2',
#      'therapy': 'ther_62',
#      'successful': 57},
#     {'id': 'c3_t1',
#      'start': datetime.date(2018, 4, 10),
#      'end': datetime.date(2018, 4, 14),
#      'condition': 'c3',
#      'therapy': 'ther_38',
#      'successful': 6},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 9, 2),
#      'end': datetime.date(2019, 10, 3),
#      'condition': 'c3',
#      'therapy': 'ther_14',
#      'successful': 13}]},
#   {'id': 'pat_393',
#    'name': 'Valeria',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2009, 2, 7),
#      'cured': None,
#      'kind': 'cond_203'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2014, 2, 27),
#      'end': datetime.date(2016, 3, 7),
#      'condition': 'c1',
#      'therapy': 'ther_61',
#      'successful': 31}]},
#   {'id': 'pat_394',
#    'name': 'Andrea',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2001, 5, 5),
#      'cured': None,
#      'kind': 'cond_186'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2008, 6, 22),
#      'cured': datetime.date(2019, 12, 28),
#      'kind': 'cond_68'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 3, 14),
#      'cured': None,
#      'kind': 'cond_191'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 8, 18),
#      'cured': datetime.date(2019, 2, 23),
#      'kind': 'cond_297'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 11, 28),
#      'cured': None,
#      'kind': 'cond_97'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2002, 7, 22),
#      'end': datetime.date(2014, 5, 28),
#      'condition': 'c1',
#      'therapy': 'ther_4',
#      'successful': 12},
#     {'id': 'c1_t2',
#      'start': datetime.date(2014, 9, 3),
#      'end': datetime.date(2016, 9, 10),
#      'condition': 'c1',
#      'therapy': 'ther_20',
#      'successful': 67},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 5, 12),
#      'end': datetime.date(2019, 7, 14),
#      'condition': 'c1',
#      'therapy': 'ther_50',
#      'successful': 45},
#     {'id': 'c1_t4',
#      'start': datetime.date(2019, 11, 11),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c1',
#      'therapy': 'ther_59',
#      'successful': 6},
#     {'id': 'c2_t1',
#      'start': datetime.date(2011, 1, 5),
#      'end': datetime.date(2015, 7, 17),
#      'condition': 'c2',
#      'therapy': 'ther_50',
#      'successful': 57},
#     {'id': 'c2_t2',
#      'start': datetime.date(2015, 12, 17),
#      'end': datetime.date(2019, 10, 26),
#      'condition': 'c2',
#      'therapy': 'ther_61',
#      'successful': 43},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 12, 28),
#      'end': datetime.date(2019, 12, 28),
#      'condition': 'c2',
#      'therapy': 'ther_8',
#      'successful': 81},
#     {'id': 'c3_t1',
#      'start': datetime.date(2015, 7, 28),
#      'end': datetime.date(2018, 1, 21),
#      'condition': 'c3',
#      'therapy': 'ther_26',
#      'successful': 65},
#     {'id': 'c3_t2',
#      'start': datetime.date(2019, 12, 9),
#      'end': datetime.date(2019, 12, 27),
#      'condition': 'c3',
#      'therapy': 'ther_61',
#      'successful': 42},
#     {'id': 'c3_t3',
#      'start': datetime.date(2019, 12, 28),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c3',
#      'therapy': 'ther_21',
#      'successful': 71},
#     {'id': 'c3_t4',
#      'start': datetime.date(2019, 12, 31),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c3',
#      'therapy': 'ther_4',
#      'successful': 26},
#     {'id': 'c4_t1',
#      'start': datetime.date(2013, 3, 31),
#      'end': datetime.date(2017, 8, 24),
#      'condition': 'c4',
#      'therapy': 'ther_20',
#      'successful': 44},
#     {'id': 'c4_t2',
#      'start': datetime.date(2019, 1, 18),
#      'end': datetime.date(2019, 2, 23),
#      'condition': 'c4',
#      'therapy': 'ther_7',
#      'successful': 84},
#     {'id': 'c5_t1',
#      'start': datetime.date(2013, 9, 7),
#      'end': datetime.date(2016, 12, 3),
#      'condition': 'c5',
#      'therapy': 'ther_9',
#      'successful': 64},
#     {'id': 'c5_t2',
#      'start': datetime.date(2017, 2, 6),
#      'end': datetime.date(2018, 11, 18),
#      'condition': 'c5',
#      'therapy': 'ther_62',
#      'successful': 75},
#     {'id': 'c5_t3',
#      'start': datetime.date(2019, 8, 29),
#      'end': datetime.date(2019, 12, 26),
#      'condition': 'c5',
#      'therapy': 'ther_39',
#      'successful': 57},
#     {'id': 'c5_t4',
#      'start': datetime.date(2019, 12, 30),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c5',
#      'therapy': 'ther_19',
#      'successful': 47}]},
#   {'id': 'pat_395',
#    'name': 'Caterina',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2003, 7, 15),
#      'cured': datetime.date(2016, 4, 1),
#      'kind': 'cond_81'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2004, 1, 24),
#      'cured': datetime.date(2010, 10, 22),
#      'kind': 'cond_2'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2008, 6, 19),
#      'end': datetime.date(2016, 4, 1),
#      'condition': 'c1',
#      'therapy': 'ther_8',
#      'successful': 82},
#     {'id': 'c2_t1',
#      'start': datetime.date(2004, 3, 22),
#      'end': datetime.date(2008, 4, 25),
#      'condition': 'c2',
#      'therapy': 'ther_13',
#      'successful': 68},
#     {'id': 'c2_t2',
#      'start': datetime.date(2008, 5, 9),
#      'end': datetime.date(2010, 10, 22),
#      'condition': 'c2',
#      'therapy': 'ther_14',
#      'successful': 97}]},
#   {'id': 'pat_396',
#    'name': 'Donatella',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2006, 5, 4),
#      'cured': datetime.date(2019, 12, 12),
#      'kind': 'cond_149'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2006, 9, 20),
#      'cured': None,
#      'kind': 'cond_244'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2009, 1, 5),
#      'cured': None,
#      'kind': 'cond_105'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2009, 8, 22),
#      'cured': None,
#      'kind': 'cond_194'},
#     {'id': 'c5',
#      'diagnosed': datetime.date(2009, 10, 27),
#      'cured': datetime.date(2019, 2, 2),
#      'kind': 'cond_273'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2017, 2, 12),
#      'end': datetime.date(2018, 10, 19),
#      'condition': 'c1',
#      'therapy': 'ther_3',
#      'successful': 25},
#     {'id': 'c1_t2',
#      'start': datetime.date(2018, 10, 25),
#      'end': datetime.date(2019, 5, 17),
#      'condition': 'c1',
#      'therapy': 'ther_40',
#      'successful': 60},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 11, 26),
#      'end': datetime.date(2019, 12, 12),
#      'condition': 'c1',
#      'therapy': 'ther_37',
#      'successful': 96},
#     {'id': 'c2_t1',
#      'start': datetime.date(2012, 7, 27),
#      'end': datetime.date(2015, 10, 28),
#      'condition': 'c2',
#      'therapy': 'ther_23',
#      'successful': 13},
#     {'id': 'c2_t2',
#      'start': datetime.date(2018, 12, 21),
#      'end': datetime.date(2019, 7, 16),
#      'condition': 'c2',
#      'therapy': 'ther_38',
#      'successful': 66},
#     {'id': 'c2_t3',
#      'start': datetime.date(2019, 12, 30),
#      'end': datetime.date(2019, 12, 30),
#      'condition': 'c2',
#      'therapy': 'ther_10',
#      'successful': 69},
#     {'id': 'c3_t1',
#      'start': datetime.date(2018, 7, 29),
#      'end': datetime.date(2018, 10, 24),
#      'condition': 'c3',
#      'therapy': 'ther_0',
#      'successful': 60},
#     {'id': 'c4_t1',
#      'start': datetime.date(2017, 4, 8),
#      'end': datetime.date(2018, 5, 17),
#      'condition': 'c4',
#      'therapy': 'ther_44',
#      'successful': 44},
#     {'id': 'c5_t1',
#      'start': datetime.date(2014, 3, 18),
#      'end': datetime.date(2019, 2, 2),
#      'condition': 'c5',
#      'therapy': 'ther_36',
#      'successful': 90}]},
#   {'id': 'pat_397',
#    'name': 'Marcella',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2004, 10, 4),
#      'cured': None,
#      'kind': 'cond_33'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2006, 4, 21),
#      'cured': None,
#      'kind': 'cond_283'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2014, 7, 30),
#      'end': datetime.date(2019, 11, 11),
#      'condition': 'c1',
#      'therapy': 'ther_35',
#      'successful': 39},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 11, 26),
#      'end': datetime.date(2019, 12, 29),
#      'condition': 'c1',
#      'therapy': 'ther_41',
#      'successful': 51},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 12, 30),
#      'end': datetime.date(2019, 12, 31),
#      'condition': 'c1',
#      'therapy': 'ther_29',
#      'successful': 12},
#     {'id': 'c2_t1',
#      'start': datetime.date(2016, 9, 1),
#      'end': datetime.date(2016, 10, 28),
#      'condition': 'c2',
#      'therapy': 'ther_65',
#      'successful': 21}]},
#   {'id': 'pat_398',
#    'name': 'Massimo',
#    'gender': 'Male',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2002, 3, 1),
#      'cured': None,
#      'kind': 'cond_254'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2007, 4, 25),
#      'cured': datetime.date(2014, 7, 20),
#      'kind': 'cond_84'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2007, 12, 29),
#      'cured': None,
#      'kind': 'cond_172'},
#     {'id': 'c4',
#      'diagnosed': datetime.date(2008, 1, 19),
#      'cured': datetime.date(2019, 12, 3),
#      'kind': 'cond_117'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2006, 6, 26),
#      'end': datetime.date(2018, 3, 1),
#      'condition': 'c1',
#      'therapy': 'ther_48',
#      'successful': 50},
#     {'id': 'c2_t1',
#      'start': datetime.date(2009, 10, 9),
#      'end': datetime.date(2014, 7, 20),
#      'condition': 'c2',
#      'therapy': 'ther_50',
#      'successful': 90},
#     {'id': 'c3_t1',
#      'start': datetime.date(2019, 3, 10),
#      'end': datetime.date(2019, 9, 12),
#      'condition': 'c3',
#      'therapy': 'ther_23',
#      'successful': 73},
#     {'id': 'c4_t1',
#      'start': datetime.date(2016, 5, 11),
#      'end': datetime.date(2018, 5, 3),
#      'condition': 'c4',
#      'therapy': 'ther_16',
#      'successful': 56},
#     {'id': 'c4_t2',
#      'start': datetime.date(2018, 9, 12),
#      'end': datetime.date(2019, 12, 3),
#      'condition': 'c4',
#      'therapy': 'ther_26',
#      'successful': 96}]},
#   {'id': 'pat_399',
#    'name': 'Anita',
#    'gender': 'Female',
#    'conditions': [{'id': 'c1',
#      'diagnosed': datetime.date(2001, 4, 30),
#      'cured': None,
#      'kind': 'cond_22'},
#     {'id': 'c2',
#      'diagnosed': datetime.date(2004, 12, 30),
#      'cured': None,
#      'kind': 'cond_81'},
#     {'id': 'c3',
#      'diagnosed': datetime.date(2007, 11, 10),
#      'cured': datetime.date(2015, 6, 5),
#      'kind': 'cond_92'}],
#    'trials': [{'id': 'c1_t1',
#      'start': datetime.date(2012, 8, 5),
#      'end': datetime.date(2015, 11, 15),
#      'condition': 'c1',
#      'therapy': 'ther_18',
#      'successful': 48},
#     {'id': 'c1_t2',
#      'start': datetime.date(2019, 1, 29),
#      'end': datetime.date(2019, 4, 22),
#      'condition': 'c1',
#      'therapy': 'ther_16',
#      'successful': 73},
#     {'id': 'c1_t3',
#      'start': datetime.date(2019, 7, 18),
#      'end': datetime.date(2019, 12, 15),
#      'condition': 'c1',
#      'therapy': 'ther_11',
#      'successful': 17},
#     {'id': 'c2_t1',
#      'start': datetime.date(2014, 7, 22),
#      'end': datetime.date(2017, 9, 22),
#      'condition': 'c2',
#      'therapy': 'ther_9',
#      'successful': 66},
#     {'id': 'c3_t1',
#      'start': datetime.date(2014, 11, 10),
#      'end': datetime.date(2015, 6, 5),
#      'condition': 'c3',
#      'therapy': 'ther_13',
#      'successful': 77}]}]}

# %% [markdown]
# #### **Compose and store the final data**
#
# The last step of our data collection is merging all the dictionaries (the conditions & therapies with the patients one).

# %%
# bind the dictionaries
final_data_dict = cond_and_ther | full_patients_dict

# save it as .json
with open('../../data/full_data.json', 'w') as fp:
    json.dump(final_data_dict, fp, indent=4, default=str)
print("> JSON stored correctly")
# Out:
# > JSON stored correctly
